# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df_bikes = pd.read_csv('edinburgh_bikes.csv')
df_bikes = df_bikes.drop(columns=['Unnamed: 0'])
df_bikes
# Out:
#         index           started_at             ended_at  duration  \
# 0           0  2018-09-15 08:52:05  2018-09-15 09:11:48      1182
# 1           1  2018-09-15 09:24:33  2018-09-15 09:41:09       995
# 2           2  2018-09-15 09:48:54  2018-09-15 10:46:40      3466
# 3           3  2018-09-16 12:01:36  2018-09-16 12:25:26      1430
# 4           4  2018-09-16 12:03:43  2018-09-16 12:11:16       452
# ...       ...                  ...                  ...       ...
# 438254  12636  2021-06-30 23:30:31  2021-07-01 00:06:10      2139
# 438255  12637  2021-06-30 23:36:16  2021-07-01 00:05:40      1763
# 438256  12638  2021-06-30 23:49:03  2021-07-01 00:11:25      1342
# 438257  12639  2021-06-30 23:49:03  2021-07-01 00:11:52      1369
# 438258  12640  2021-06-30 23:58:33  2021-07-01 00:07:15       522
#
#         start_station_id start_station_name         start_station_description  \
# 0                    247   Charlotte Square  North Corner of Charlotte Square
# 1                    259   St Andrew Square                 North East corner
# 2                    262         Canonmills                      near Tesco's
# 3                    255  Kings Buildings 4                          X-Y Cafe
# 4                    255  Kings Buildings 4                          X-Y Cafe
# ...                  ...                ...                               ...
# 438254              1090  Hillside Crescent     East end of Hillside Crescent
# 438255              1814          Abbeyhill                  Near Abbey Mount
# 438256               256   St Andrews House              beside Jacobs ladder
# 438257               256   St Andrews House              beside Jacobs ladder
# 438258               247   Charlotte Square  North Corner of Charlotte Square
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 0                    55.952335                -3.207101             259
# 1                    55.954749                -3.192774             262
# 2                    55.962804                -3.196284             250
# 3                    55.922001                -3.176902             254
# 4                    55.922001                -3.176902             253
# ...                        ...                      ...             ...
# 438254               55.957872                -3.175888            1728
# 438255               55.955248                -3.172216            1728
# 438256               55.953164                -3.181682            1091
# 438257               55.953164                -3.181682            1091
# 438258               55.952335                -3.207101            1769
#
#                end_station_name                   end_station_description  \
# 0              St Andrew Square                         North East corner
# 1                    Canonmills                              near Tesco's
# 2                 Victoria Quay    Entrance to Scottish Government Office
# 3              Kings Building 3                      Kings Building House
# 4              Kings Building 2                        Sanderson Building
# ...                         ...                                       ...
# 438254  Portobello - Kings Road  Foot of Kings Road next to the promenade
# 438255  Portobello - Kings Road  Foot of Kings Road next to the promenade
# 438256            Holyrood Road                 Opposite St Leonards Land
# 438257            Holyrood Road                 Opposite St Leonards Land
# 438258          Brunswick Place        Corner of Elm Row/Brunswick Street
#
#         end_station_latitude  end_station_longitude
# 0                  55.954728              -3.192653
# 1                  55.962804              -3.196284
# 2                  55.977638              -3.174116
# 3                  55.923479              -3.175385
# 4                  55.923202              -3.171646
# ...                      ...                    ...
# 438254             55.957915              -3.118332
# 438255             55.957915              -3.118332
# 438256             55.949560              -3.180413
# 438257             55.949560              -3.180413
# 438258             55.960852              -3.180986
#
# [438259 rows x 14 columns]

# %%
# creating new columns in type = datetime
df_bikes['started_at_dt'] = pd.to_datetime(df_bikes['started_at'])
df_bikes['ended_at_dt'] = pd.to_datetime(df_bikes['ended_at'])

# creating new column by subtracting two columns
df_bikes['time_difference'] = df_bikes['ended_at_dt']\
                            - df_bikes['started_at_dt']

# sorting values to see shortest and longest rides
df_timedif = df_bikes[
    ['started_at', 
     'ended_at', 
     'duration', 
     'time_difference']
    ].sort_values('time_difference')
df_timedif
# Out:
#                  started_at             ended_at  duration  time_difference
# 352191  2020-10-30 17:01:58  2020-10-30 17:02:59        61  0 days 00:01:01
# 149873  2020-02-04 13:24:13  2020-02-04 13:25:14        61  0 days 00:01:01
# 10233   2018-11-30 12:47:07  2018-11-30 12:48:08        61  0 days 00:01:01
# 284869  2020-08-08 08:54:30  2020-08-08 08:55:31        61  0 days 00:01:01
# 106754  2019-09-28 09:47:22  2019-09-28 09:48:23        61  0 days 00:01:01
# ...                     ...                  ...       ...              ...
# 14913   2019-01-05 18:40:07  2019-01-13 18:00:39    688832  7 days 23:20:32
# 161588  2020-03-07 13:18:28  2020-03-15 16:04:37    701168  8 days 02:46:09
# 13026   2018-12-22 19:39:49  2019-01-03 09:39:00   1000750 11 days 13:59:11
# 141002  2020-01-10 15:46:22  2020-01-22 14:40:21   1032838 11 days 22:53:59
# 12423   2018-12-18 10:40:20  2019-01-14 19:09:28   2363348 27 days 08:29:08
#
# [438259 rows x 4 columns]

# %%
#@markdown As we can see in the plot below, there are only a few outlying values that distort our observations.
fig, ax = plt.subplots(1, 1, figsize=(15,5))
df_bikes.plot.scatter('duration', 'index', ax=ax)

ax.grid(alpha=0.3)
ax.title.set_text('Length of rides')

# %%
hours =   4#@param {type:"number"} 

# plot a diagram
fig, ax = plt.subplots(figsize=(15,5))
df_bikes.plot.scatter('duration', 'index', ax=ax)

ax.grid(alpha=0.3)
ax.title.set_text('Length of rides')
ax.set_xlim([0, hours*3600])

# calculate, how many values were cut as outlying values
whole_dataframe = df_timedif.shape[0]
trimed_dataframe = df_bikes[df_timedif['duration'] < hours*3600].shape[0]
trimed = 100 - (trimed_dataframe / whole_dataframe * 100)
print(f'Percentage of cut rides from plot: {round(trimed, 3)}%')
# Out:
# C:\Users\Radim Jedlicka\AppData\Local\Temp/ipykernel_30608/3817953513.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   trimed_dataframe = df_bikes[df_timedif['duration'] < hours*3600].shape[0]
# Percentage of cut rides from plot: 0.501%

# %%
#@markdown Show histogram of our rides

px.histogram(
    df_timedif,
    x='duration',
    histnorm='percent',
    labels={'duration': 'Duration of rides in seconds'},
    range_x=[0, hours*3600],
    title='Histogram of duration of rides in dataframe',
    width=1000,
    height=500
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30608/3076930729.py in <module>
#       1 #@markdown Show histogram of our rides
#       2
# ----> 3 px.histogram(
#       4     df_timedif,
#       5     x='duration',
#
# NameError: name 'px' is not defined
